# %% [markdown]
# ## SUMMARY: Will correct the h5 prediction files for all of the single instance videos

# %% [markdown]
# # get single vids

# %%
import os
import random
import h5py
import numpy as np
import time

from utils import find_node_velocity, get_stats, fill_missing, graph_vels, nan_vals

# %%
defaultdir = '/gpfs/radev/pi/saxena/aj764'
rootdir = f'{defaultdir}/PairedTestingSessions/'

# %% [markdown]
# Compiles a list of all of the sessions in PairedTestingSessions that have a Videos folder in them

# %%
vid_subdirs = []
for subdir, dirs, files in os.walk(rootdir):
    if subdir.endswith("Videos"):
        vid_subdirs.append(subdir)
vid_subdirs = sorted(vid_subdirs)

# %% [markdown]
# Seperates all of the videos into single instance videos and multi instance videos (and takes out videos from before April).

# %%
single_vids = {}
multi_vids = {}
for vids in vid_subdirs:
    files = os.listdir(vids)
    cut_vids = vids[28:]
    single_vids[cut_vids] = []
    multi_vids[cut_vids] = []
    for file in files:
        if file.endswith('.mp4') and int(file[:2]) >= 4:
            KL_count = file.count('KL')
            EB_count = file.count('EB')
            HF_count = file.count('HF')
            if KL_count + EB_count + HF_count == 2:
                multi_vids[cut_vids].append(file)
            else:
                single_vids[cut_vids].append(file)

# %%
single_len_tot = 0
for key, value in single_vids.items():
    single_len_tot += len(value)
print(f'There are {single_len_tot} single instance videos')
# Out:
# There are 1106 single instance videos

# %%
multi_len_tot = 0
for key, value in multi_vids.items():
    multi_len_tot += len(value)
print(f'There are {multi_len_tot} multi instance videos')
# Out:
# There are 905 multi instance videos

# %% [markdown]
# Fills in the NaN values for all of the single instance files

# %% [markdown]
# # fills in missing vals

# %%
CHECK = False
actually_fill = False # will also have to change file open to "r+"

# %%
start_time = time.time()

total_intial_nan = 0
total_after_out_nan = 0
total_final_nan = 0
total_after_check_nan = 0

all_errors = np.empty((single_len_tot, 4))
all_vids = []

count = 0
for i, session in enumerate(single_vids.keys()): 
    video_list = single_vids[session]
    analysis_path = defaultdir + '/' + session[:-6] + 'Tracking/h5/'
    
    for video in video_list:
        # open analysis file
        analysis_file = analysis_path + video[:-3] + 'predictions.h5'
        with h5py.File(analysis_file,'r') as f:
            locations = f["tracks"][:].T 

            # find nan values
            intial = nan_vals(locations)

            # just to check you haven't already done this vid or it isn't empty
            if intial != 0:
                # take out positional outliers
                all_vels = {}
                for node in range(locations.shape[1]):
                    # find the velocities
                    all_vels[node] = find_node_velocity(locations[:, node, :])
                
                    # get values need to find outliers
                    mean, std, low, high = get_stats(all_vels[node])
                
                    # if you want to check that these values looks good
                    graph_vels(all_vels[node], CHECK)
                
                    # replace outliers in locations with nan
                    nan_index = [i for i in range(len(all_vels[node])) if (all_vels[node][i] > high or all_vels[node][i] < low)]
                    for index in nan_index:
                        locations[index + 1, node, 0], locations[index + 1, node, 0] = np.nan, np.nan
                
                    # if you want to check that new locations look good
                    test_vels = find_node_velocity(locations[:, node, :])
                    graph_vels(test_vels, check=CHECK, old_low=low, old_high=high)
    
                # find nan values again
                after_out = nan_vals(locations)
    
                # fill in missing locations
                print(f'video name: {video}')
                new_locations = fill_missing(locations)
                if actually_fill:
                    f["tracks"][:] = new_locations.T

                # finds nan values after filling
                after_fill = nan_vals(new_locations)

                # take out positional outliers again (to make sure we aren't filling in stupid stuff...?
                all_vels = {}
                for node in range(locations.shape[1]):
                    # find the velocities
                    all_vels[node] = find_node_velocity(new_locations[:, node, :])
                
                    # get values need to find outliers
                    mean, std, low, high = get_stats(all_vels[node])
                
                    # if you want to check that these values looks good
                    graph_vels(all_vels[node], CHECK)
                
                    # replace outliers in locations with nan
                    nan_index = [i for i in range(len(all_vels[node])) if (all_vels[node][i] > high or all_vels[node][i] < low)]
                    for index in nan_index:
                        new_locations[index + 1, node, 0], new_locations[index + 1, node, 0] = np.nan, np.nan
                
                    # if you want to check that new locations look good
                    test_vels = find_node_velocity(new_locations[:, node, :])
                    graph_vels(test_vels, check=CHECK, old_low=low, old_high=high)
                
                after_check = nan_vals(new_locations)
                
                total_intial_nan += intial
                total_after_out_nan += after_out
                total_final_nan += after_fill
                total_after_check_nan += after_check
                all_errors[count, :] = [intial, after_out, after_fill, after_check]
                all_vids.append(video)
                count += 1
    
                # if you want to check the nan/fill values for a each video
                if True:
                    # print(f'video name: {video}')
                    print(f'intial nan: {round(intial, 2)} %, after out nan: {round(after_out, 2)} %, final nan: {round(after_fill, 2)} %, after check nan: {round(after_check, 2)} %')
        
print('totals:')
print(f'intial nan: {round(total_intial_nan / single_len_tot, 2)} %, after out nan: {round(total_after_out_nan / single_len_tot, 2)} %, final nan: {round(total_final_nan / single_len_tot, 2)} %, after check nan: {round(total_after_check_nan / single_len_tot, 2)} %')
print(f'time elapse: {time.time() - start_time}')
# Out:
# video name: 041624_Cam4_TrNum13_IS_KL001Y.mp4
# intial nan: 1.86 %, after out nan: 2.57 %, final nan: 0.0 %, after check nan: 0.51 %
# video name: 041624_Cam4_TrNum1_IS_KL001B.mp4
# intial nan: 3.05 %, after out nan: 3.99 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 041624_Cam4_TrNum4_IS_KL001Y.mp4
# intial nan: 2.81 %, after out nan: 3.95 %, final nan: 0.0 %, after check nan: 1.24 %
# video name: 041624_Cam4_TrNum16_IS_KL001B.mp4
# intial nan: 2.37 %, after out nan: 2.96 %, final nan: 0.0 %, after check nan: 0.46 %
# video name: 041624_Cam4_TrNum14_PV_KL001G.mp4
# intial nan: 1.95 %, after out nan: 2.55 %, final nan: 0.0 %, after check nan: 0.41 %
# video name: 041624_Cam4_TrNum15_PV_KL001R.mp4
# intial nan: 2.47 %, after out nan: 3.24 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 041624_Cam4_TrNum3_PV_KL001R.mp4
# intial nan: 3.56 %, after out nan: 4.42 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 041624_Cam4_TrNum2_PV_KL001G.mp4
# intial nan: 1.72 %, after out nan: 2.66 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 041624_Cam3_TrNum2_PV_KL002R.mp4
# intial nan: 1.17 %, after out nan: 1.84 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 041624_Cam3_TrNum3_PV_KL002G.mp4
# intial nan: 5.26 %, after out nan: 6.23 %, final nan: 0.0 %, after check nan: 1.13 %
# video name: 041624_Cam3_TrNum15_IS_KL002B.mp4
# intial nan: 0.65 %, after out nan: 1.38 %, final nan: 0.0 %, after check nan: 0.66 %
# video name: 041624_Cam3_TrNum16_PV_KL002G.mp4
# intial nan: 1.73 %, after out nan: 2.26 %, final nan: 0.0 %, after check nan: 0.44 %
# video name: 041624_Cam3_TrNum1_IS_KL002Y.mp4
# intial nan: 2.18 %, after out nan: 3.18 %, final nan: 0.0 %, after check nan: 1.09 %
# video name: 041624_Cam3_TrNum4_IS_KL002B.mp4
# intial nan: 2.37 %, after out nan: 2.96 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 041624_Cam3_TrNum13_IS_KL002Y.mp4
# intial nan: 5.09 %, after out nan: 5.87 %, final nan: 0.0 %, after check nan: 0.96 %
# video name: 041624_Cam3_TrNum14_PV_KL002R.mp4
# intial nan: 2.27 %, after out nan: 2.86 %, final nan: 0.0 %, after check nan: 0.83 %
# video name: 041624_Cam2_TrNum3_PV_KL003Y.mp4
# intial nan: 3.32 %, after out nan: 4.0 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 041624_Cam2_TrNum16_PV_KL003Y.mp4
# intial nan: 2.68 %, after out nan: 3.19 %, final nan: 0.0 %, after check nan: 0.38 %
# video name: 041624_Cam2_TrNum2_IS_KL003B.mp4
# intial nan: 2.04 %, after out nan: 2.98 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 041624_Cam2_TrNum14_IS_KL003G.mp4
# intial nan: 4.84 %, after out nan: 5.85 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 041624_Cam2_TrNum4_PV_KL003R.mp4
# intial nan: 3.91 %, after out nan: 4.79 %, final nan: 0.0 %, after check nan: 0.82 %
# video name: 041624_Cam2_TrNum1_IS_KL003G.mp4
# intial nan: 4.59 %, after out nan: 5.36 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 041624_Cam2_TrNum15_PV_KL003R.mp4
# intial nan: 2.71 %, after out nan: 3.51 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 041624_Cam2_TrNum13_IS_KL003B.mp4
# intial nan: 2.22 %, after out nan: 2.91 %, final nan: 0.0 %, after check nan: 0.64 %
# video name: 041624_Cam1_TrNum2_PV_KL004B.mp4
# intial nan: 2.66 %, after out nan: 3.33 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 041624_Cam1_TrNum3_IS_KL004G.mp4
# intial nan: 1.85 %, after out nan: 2.5 %, final nan: 0.0 %, after check nan: 0.63 %
# video name: 041624_Cam1_TrNum16_IS_KL004G.mp4
# intial nan: 2.87 %, after out nan: 3.91 %, final nan: 0.0 %, after check nan: 1.08 %
# video name: 041624_Cam1_TrNum14_PV_KL004Y.mp4
# intial nan: 3.99 %, after out nan: 4.69 %, final nan: 0.0 %, after check nan: 0.63 %
# video name: 041624_Cam1_TrNum4_PV_KL004Y.mp4
# intial nan: 3.37 %, after out nan: 3.98 %, final nan: 0.0 %, after check nan: 0.58 %
# video name: 041624_Cam1_TrNum15_PV_KL004B.mp4
# intial nan: 4.06 %, after out nan: 5.03 %, final nan: 0.0 %, after check nan: 0.96 %
# video name: 041624_Cam1_TrNum1_IS_KL004R.mp4
# intial nan: 13.17 %, after out nan: 14.04 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 041624_Cam1_TrNum13_IS_KL004R.mp4
# intial nan: 3.92 %, after out nan: 4.95 %, final nan: 0.0 %, after check nan: 1.02 %
# video name: 041824_Cam4_TrNum14_IS_KL005B.mp4
# intial nan: 1.12 %, after out nan: 2.02 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 041824_Cam4_TrNum13_IS_KL005Y.mp4
# intial nan: 1.44 %, after out nan: 2.21 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 041824_Cam4_TrNum2_IS_KL005B.mp4
# intial nan: 1.55 %, after out nan: 2.35 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 041824_Cam4_TrNum15_PV_KL005G.mp4
# intial nan: 1.61 %, after out nan: 2.6 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 041824_Cam4_TrNum3_PV_KL005R.mp4
# intial nan: 2.12 %, after out nan: 3.01 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 041824_Cam4_TrNum4_PV_KL005G.mp4
# intial nan: 1.63 %, after out nan: 2.63 %, final nan: 0.0 %, after check nan: 1.1 %
# video name: 041824_Cam4_TrNum16_PV_KL005R.mp4
# intial nan: 1.61 %, after out nan: 2.84 %, final nan: 0.0 %, after check nan: 1.28 %
# video name: 041824_Cam4_TrNum1_IS_KL005Y.mp4
# intial nan: 2.44 %, after out nan: 3.47 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 041824_Cam1_TrNum13_IS_KL006G.mp4
# intial nan: 1.65 %, after out nan: 2.68 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 041824_Cam1_TrNum16_IS_KL006R.mp4
# intial nan: 1.8 %, after out nan: 2.48 %, final nan: 0.0 %, after check nan: 0.58 %
# video name: 041824_Cam1_TrNum2_PV_KL006Y.mp4
# intial nan: 9.17 %, after out nan: 10.15 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 041824_Cam1_TrNum14_PV_KL006Y.mp4
# intial nan: 2.73 %, after out nan: 3.95 %, final nan: 0.0 %, after check nan: 1.34 %
# video name: 041824_Cam1_TrNum1_IS_KL006G.mp4
# intial nan: 7.3 %, after out nan: 8.2 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 041824_Cam1_TrNum3_IS_KL006R.mp4
# intial nan: 5.41 %, after out nan: 6.33 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 041824_Cam1_TrNum4_PV_KL006B.mp4
# intial nan: 9.47 %, after out nan: 10.29 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 041824_Cam1_TrNum15_PV_KL006B.mp4
# intial nan: 3.96 %, after out nan: 5.02 %, final nan: 0.0 %, after check nan: 1.1 %
# video name: 041824_Cam3_TrNum13_PV_KL007B.mp4
# intial nan: 1.15 %, after out nan: 1.91 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 041824_Cam3_TrNum4_IS_KL007G.mp4
# intial nan: 1.38 %, after out nan: 2.21 %, final nan: 0.0 %, after check nan: 0.91 %
# video name: 041824_Cam3_TrNum16_PV_KL007R.mp4
# intial nan: 2.16 %, after out nan: 3.1 %, final nan: 0.0 %, after check nan: 0.96 %
# video name: 041824_Cam3_TrNum3_PV_KL007B.mp4
# intial nan: 1.83 %, after out nan: 2.5 %, final nan: 0.0 %, after check nan: 0.58 %
# video name: 041824_Cam3_TrNum14_IS_KL007G.mp4
# intial nan: 0.96 %, after out nan: 1.93 %, final nan: 0.0 %, after check nan: 1.17 %
# video name: 041824_Cam3_TrNum1_PV_KL007R.mp4
# intial nan: 1.7 %, after out nan: 2.5 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 041824_Cam3_TrNum2_IS_KL007Y.mp4
# intial nan: 3.37 %, after out nan: 4.06 %, final nan: 0.0 %, after check nan: 0.64 %
# video name: 041824_Cam3_TrNum15_IS_KL007Y.mp4
# intial nan: 0.96 %, after out nan: 1.54 %, final nan: 0.0 %, after check nan: 0.43 %
# video name: 041824_Cam2_TrNum13_IS_KL008G.mp4
# intial nan: 7.36 %, after out nan: 8.31 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 041824_Cam2_TrNum14_PV_KL008R.mp4
# intial nan: 2.52 %, after out nan: 3.59 %, final nan: 0.0 %, after check nan: 1.22 %
# video name: 041824_Cam2_TrNum4_PV_KL008Y.mp4
# intial nan: 3.79 %, after out nan: 4.51 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 041824_Cam2_TrNum1_IS_KL008B.mp4
# intial nan: 3.33 %, after out nan: 4.15 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 041824_Cam2_TrNum3_PV_KL008R.mp4
# intial nan: 3.86 %, after out nan: 4.68 %, final nan: 0.0 %, after check nan: 0.83 %
# video name: 041824_Cam2_TrNum15_IS_KL008B.mp4
# intial nan: 2.64 %, after out nan: 3.55 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 041824_Cam2_TrNum2_IS_KL008G.mp4
# intial nan: 4.29 %, after out nan: 4.85 %, final nan: 0.0 %, after check nan: 0.5 %
# video name: 041824_Cam2_TrNum16_PV_KL008Y.mp4
# intial nan: 3.79 %, after out nan: 4.74 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 041924_Cam2_TrNum1_PV_KL001G.mp4
# intial nan: 4.56 %, after out nan: 5.43 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 041924_Cam2_TrNum14_PV_KL001G.mp4
# intial nan: 3.3 %, after out nan: 4.26 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 041924_Cam2_TrNum15_PV_KL001R.mp4
# intial nan: 4.69 %, after out nan: 5.46 %, final nan: 0.0 %, after check nan: 0.77 %
# video name: 041924_Cam2_TrNum2_IS_KL001Y.mp4
# intial nan: 3.79 %, after out nan: 4.71 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 041924_Cam2_TrNum16_IS_KL001Y.mp4
# intial nan: 2.23 %, after out nan: 3.15 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 041924_Cam2_TrNum4_PV_KL001R.mp4
# intial nan: 4.94 %, after out nan: 5.71 %, final nan: 0.0 %, after check nan: 0.75 %
# video name: 041924_Cam2_TrNum3_IS_KL001B.mp4
# intial nan: 3.58 %, after out nan: 4.34 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 041924_Cam2_TrNum13_IS_KL001B.mp4
# intial nan: 2.7 %, after out nan: 3.42 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 041924_Cam4_TrNum3_PV_KL002G.mp4
# intial nan: 2.77 %, after out nan: 4.01 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 041924_Cam4_TrNum16_PV_KL002R.mp4
# intial nan: 2.44 %, after out nan: 3.12 %, final nan: 0.0 %, after check nan: 0.64 %
# video name: 041924_Cam4_TrNum2_IS_KL002B.mp4
# intial nan: 1.96 %, after out nan: 3.06 %, final nan: 0.0 %, after check nan: 1.18 %
# video name: 041924_Cam4_TrNum1_PV_KL002R.mp4
# intial nan: 1.74 %, after out nan: 2.87 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 041924_Cam4_TrNum4_IS_KL002Y.mp4
# intial nan: 1.51 %, after out nan: 2.42 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 041924_Cam4_TrNum15_PV_KL002G.mp4
# intial nan: 3.53 %, after out nan: 4.38 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 041924_Cam4_TrNum13_IS_KL002Y.mp4
# intial nan: 2.38 %, after out nan: 3.17 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 041924_Cam4_TrNum14_IS_KL002B.mp4
# intial nan: 1.15 %, after out nan: 2.14 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 041924_Cam3_TrNum13_IS_KL003G.mp4
# intial nan: 1.68 %, after out nan: 2.23 %, final nan: 0.0 %, after check nan: 0.38 %
# video name: 041924_Cam3_TrNum1_IS_KL003G.mp4
# intial nan: 2.0 %, after out nan: 2.8 %, final nan: 0.0 %, after check nan: 0.84 %
# video name: 041924_Cam3_TrNum16_PV_KL003Y.mp4
# intial nan: 1.07 %, after out nan: 2.19 %, final nan: 0.0 %, after check nan: 1.28 %
# video name: 041924_Cam3_TrNum15_PV_KL003R.mp4
# intial nan: 2.16 %, after out nan: 3.04 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 041924_Cam3_TrNum3_PV_KL003R.mp4
# intial nan: 1.69 %, after out nan: 2.37 %, final nan: 0.0 %, after check nan: 0.64 %
# video name: 041924_Cam3_TrNum14_IS_KL003B.mp4
# intial nan: 0.66 %, after out nan: 1.29 %, final nan: 0.0 %, after check nan: 0.59 %
# video name: 041924_Cam3_TrNum2_IS_KL003B.mp4
# intial nan: 0.92 %, after out nan: 1.83 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 041924_Cam3_TrNum4_PV_KL003Y.mp4
# intial nan: 2.35 %, after out nan: 3.07 %, final nan: 0.0 %, after check nan: 0.63 %
# video name: 041924_Cam1_TrNum16_PV_KL004Y.mp4
# intial nan: 2.72 %, after out nan: 3.32 %, final nan: 0.0 %, after check nan: 0.47 %
# video name: 041924_Cam1_TrNum15_PV_KL004B.mp4
# intial nan: 2.49 %, after out nan: 3.07 %, final nan: 0.0 %, after check nan: 0.44 %
# video name: 041924_Cam1_TrNum2_IS_KL004G.mp4
# intial nan: 1.38 %, after out nan: 2.02 %, final nan: 0.0 %, after check nan: 0.58 %
# video name: 041924_Cam1_TrNum13_IS_KL004G.mp4
# intial nan: 1.76 %, after out nan: 2.27 %, final nan: 0.0 %, after check nan: 0.43 %
# video name: 041924_Cam1_TrNum1_PV_KL004Y.mp4
# intial nan: 5.57 %, after out nan: 6.41 %, final nan: 0.0 %, after check nan: 1.02 %
# video name: 041924_Cam1_TrNum3_IS_KL004R.mp4
# intial nan: 1.63 %, after out nan: 2.52 %, final nan: 0.0 %, after check nan: 0.96 %
# video name: 041924_Cam1_TrNum4_PV_KL004B.mp4
# intial nan: 2.49 %, after out nan: 3.02 %, final nan: 0.0 %, after check nan: 0.42 %
# video name: 041924_Cam1_TrNum14_IS_KL004R.mp4
# intial nan: 1.27 %, after out nan: 2.14 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 042224_Cam2_TrNum15_PV_KL005G.mp4
# intial nan: 3.47 %, after out nan: 4.63 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 042224_Cam2_TrNum4_PV_KL005R.mp4
# intial nan: 3.21 %, after out nan: 4.22 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042224_Cam2_TrNum14_IS_KL005B.mp4
# intial nan: 2.57 %, after out nan: 3.51 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 042224_Cam2_TrNum1_IS_KL005B.mp4.mp4
# intial nan: 3.73 %, after out nan: 4.71 %, final nan: 0.0 %, after check nan: 1.02 %
# video name: 042224_Cam2_TrNum3_PV_KL005G.mp4
# intial nan: 3.52 %, after out nan: 4.41 %, final nan: 0.0 %, after check nan: 0.66 %
# video name: 042224_Cam2_TrNum16_PV_KL005R.mp4
# intial nan: 3.95 %, after out nan: 4.69 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 042224_Cam2_TrNum2_IS_KL005Y.mp4
# intial nan: 3.55 %, after out nan: 4.47 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 042224_Cam2_TrNum13_IS_KL005Y.mp4
# intial nan: 6.51 %, after out nan: 7.38 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 042224_Cam4_TrNum3_IS_KL006R.mp4
# intial nan: 1.64 %, after out nan: 2.3 %, final nan: 0.0 %, after check nan: 0.48 %
# video name: 042224_Cam4_TrNum14_PV_KL006B.mp4
# intial nan: 2.6 %, after out nan: 3.52 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042224_Cam4_TrNum15_PV_KL006Y.mp4
# intial nan: 2.2 %, after out nan: 3.14 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 042224_Cam4_TrNum13_IS_KL006G.mp4
# intial nan: 2.09 %, after out nan: 3.14 %, final nan: 0.0 %, after check nan: 1.16 %
# video name: 042224_Cam4_TrNum2_PV_KL006B.mp4
# intial nan: 2.08 %, after out nan: 3.29 %, final nan: 0.0 %, after check nan: 1.17 %
# video name: 042224_Cam4_TrNum4_PV_KL006Y.mp4
# intial nan: 1.15 %, after out nan: 2.15 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 042224_Cam4_TrNum1_IS_KL006G.mp4
# intial nan: 2.72 %, after out nan: 3.71 %, final nan: 0.0 %, after check nan: 1.1 %
# video name: 042224_Cam4_TrNum16_IS_KL006R.mp4
# intial nan: 1.82 %, after out nan: 2.52 %, final nan: 0.0 %, after check nan: 0.54 %
# video name: 042224_Cam3_TrNum3_PV_KL007B.mp4
# intial nan: 1.46 %, after out nan: 2.25 %, final nan: 0.0 %, after check nan: 0.82 %
# video name: 042224_Cam3_TrNum4_IS_KL007G.mp4
# intial nan: 1.29 %, after out nan: 2.2 %, final nan: 0.0 %, after check nan: 0.91 %
# video name: 042224_Cam3_TrNum16_PV_KL007R.mp4
# intial nan: 2.11 %, after out nan: 3.19 %, final nan: 0.0 %, after check nan: 1.19 %
# video name: 042224_Cam3_TrNum15_IS_KL007G.mp4
# intial nan: 0.67 %, after out nan: 1.45 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 042224_Cam3_TrNum13_PV_KL007B.mp4
# intial nan: 1.1 %, after out nan: 1.88 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 042224_Cam3_TrNum14_IS_KL007Y.mp4
# intial nan: 1.23 %, after out nan: 1.73 %, final nan: 0.0 %, after check nan: 0.36 %
# video name: 042224_Cam3_TrNum2_IS_KL007Y.mp4
# intial nan: 1.34 %, after out nan: 1.88 %, final nan: 0.0 %, after check nan: 0.38 %
# video name: 042224_Cam3_TrNum1_PV_KL007R.mp4
# intial nan: 1.8 %, after out nan: 2.76 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 042224_Cam1_TrNum1_PV_KL008Y.mp4
# intial nan: 2.4 %, after out nan: 3.41 %, final nan: 0.0 %, after check nan: 1.07 %
# video name: 042224_Cam1_TrNum4_IS_KL008G.mp4
# intial nan: 2.09 %, after out nan: 2.7 %, final nan: 0.0 %, after check nan: 0.57 %
# video name: 042224_Cam1_TrNum3_PV_KL008R.mp4
# intial nan: 2.48 %, after out nan: 3.39 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 042224_Cam1_TrNum14_IS_KL008B.mp4
# intial nan: 3.68 %, after out nan: 4.53 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 042224_Cam1_TrNum2_IS_KL008B.mp4
# intial nan: 1.87 %, after out nan: 2.83 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 042224_Cam1_TrNum15_IS_KL008G.mp4
# intial nan: 2.74 %, after out nan: 3.52 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 042224_Cam1_TrNum16_PV_KL008Y.mp4
# intial nan: 2.68 %, after out nan: 3.57 %, final nan: 0.0 %, after check nan: 0.82 %
# video name: 042224_Cam1_TrNum13_PV_KL008R.mp4
# intial nan: 2.49 %, after out nan: 3.12 %, final nan: 0.0 %, after check nan: 0.5 %
# video name: 042324_Cam3_TrNum1_PV_KL001G.mp4
# intial nan: 1.77 %, after out nan: 2.63 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 042324_Cam3_TrNum3_PV_KL001R.mp4
# intial nan: 2.07 %, after out nan: 2.78 %, final nan: 0.0 %, after check nan: 0.57 %
# video name: 042324_Cam3_TrNum14_PV_KL001G.mp4
# intial nan: 2.22 %, after out nan: 2.97 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 042324_Cam3_TrNum4_IS_KL001Y.mp4
# intial nan: 1.98 %, after out nan: 2.88 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 042324_Cam3_TrNum16_IS_KL001Y.mp4
# intial nan: 1.11 %, after out nan: 1.9 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 042324_Cam3_TrNum2_IS_KL001B.mp4
# intial nan: 2.34 %, after out nan: 2.96 %, final nan: 0.0 %, after check nan: 0.84 %
# video name: 042324_Cam3_TrNum15_IS_KL001B.mp4
# intial nan: 2.41 %, after out nan: 3.34 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 042324_Cam4_TrNum14_IS_KL002B.mp4
# intial nan: 0.91 %, after out nan: 1.59 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 042324_Cam4_TrNum4_PV_KL002R.mp4
# intial nan: 1.44 %, after out nan: 2.35 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 042324_Cam4_TrNum1_PV_KL002G.mp4
# intial nan: 2.92 %, after out nan: 4.05 %, final nan: 0.0 %, after check nan: 1.22 %
# video name: 042324_Cam4_TrNum15_IS_KL002Y.mp4
# intial nan: 1.69 %, after out nan: 2.55 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 042324_Cam4_TrNum2_IS_KL002Y.mp4
# intial nan: 1.19 %, after out nan: 2.3 %, final nan: 0.0 %, after check nan: 1.19 %
# video name: 042324_Cam4_TrNum3_IS_KL002B.mp4
# intial nan: 0.87 %, after out nan: 2.02 %, final nan: 0.0 %, after check nan: 1.18 %
# video name: 042324_Cam4_TrNum16_PV_KL002R.mp4
# intial nan: 1.79 %, after out nan: 2.4 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 042324_Cam2_TrNum16_PV_KL003Y.mp4
# intial nan: 4.25 %, after out nan: 5.32 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 042324_Cam2_TrNum15_IS_KL003B.mp4
# intial nan: 1.56 %, after out nan: 2.23 %, final nan: 0.0 %, after check nan: 0.55 %
# video name: 042324_Cam2_TrNum3_PV_KL003R.mp4
# intial nan: 4.96 %, after out nan: 5.81 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 042324_Cam2_TrNum1_PV_KL003Y.mp4
# intial nan: 5.04 %, after out nan: 5.96 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 042324_Cam2_TrNum14_IS_KL003G.mp4
# intial nan: 2.39 %, after out nan: 2.86 %, final nan: 0.0 %, after check nan: 0.36 %
# video name: 042324_Cam2_TrNum4_IS_KL003B.mp4
# intial nan: 1.96 %, after out nan: 2.72 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 042324_Cam2_TrNum2_IS_KL003G.mp4
# intial nan: 2.8 %, after out nan: 3.49 %, final nan: 0.0 %, after check nan: 0.55 %
# video name: 042324_Cam1_TrNum4_IS_KL004G.mp4
# intial nan: 1.22 %, after out nan: 1.84 %, final nan: 0.0 %, after check nan: 0.46 %
# video name: 042324_Cam1_TrNum2_IS_KL004R.mp4
# intial nan: 1.51 %, after out nan: 2.56 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 042324_Cam1_TrNum3_PV_KL004Y.mp4
# intial nan: 4.03 %, after out nan: 4.85 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 042324_Cam1_TrNum15_PV_KL004B.mp4
# intial nan: 4.61 %, after out nan: 5.38 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 042324_Cam1_TrNum1_PV_KL004B.mp4
# intial nan: 2.82 %, after out nan: 3.64 %, final nan: 0.0 %, after check nan: 0.77 %
# video name: 042324_Cam1_TrNum14_IS_KL004R.mp4
# intial nan: 3.8 %, after out nan: 4.66 %, final nan: 0.0 %, after check nan: 0.86 %
# video name: 042324_Cam1_TrNum16_PV_KL004Y.mp4
# intial nan: 3.72 %, after out nan: 4.3 %, final nan: 0.0 %, after check nan: 0.49 %
# video name: 042424_Cam2_TrNum15_IS_KL005B.mp4
# intial nan: 1.84 %, after out nan: 2.65 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 042424_Cam2_TrNum13_IS_KL005Y.mp4
# intial nan: 3.15 %, after out nan: 3.95 %, final nan: 0.0 %, after check nan: 0.77 %
# video name: 042424_Cam2_TrNum4_IS_KL005Y.mp4
# intial nan: 2.42 %, after out nan: 3.15 %, final nan: 0.0 %, after check nan: 0.66 %
# video name: 042424_Cam2_TrNum16_PV_KL005R.mp4
# intial nan: 4.21 %, after out nan: 5.09 %, final nan: 0.0 %, after check nan: 0.77 %
# video name: 042424_Cam2_TrNum2_IS_KL005B.mp4
# intial nan: 2.05 %, after out nan: 2.83 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042424_Cam2_TrNum3_PV_KL005G.mp4
# intial nan: 2.27 %, after out nan: 2.94 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 042424_Cam2_TrNum14_PV_KL005G.mp4
# intial nan: 4.17 %, after out nan: 5.17 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 042424_Cam2_TrNum1_PV_KL005R.mp4
# intial nan: 1.98 %, after out nan: 2.56 %, final nan: 0.0 %, after check nan: 0.54 %
# video name: 042424_Cam3_TrNum4_IS_KL006R.mp4
# intial nan: 0.67 %, after out nan: 1.46 %, final nan: 0.0 %, after check nan: 0.77 %
# video name: 042424_Cam3_TrNum3_PV_KL006B.mp4
# intial nan: 2.08 %, after out nan: 2.92 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 042424_Cam3_TrNum14_PV_KL006B.mp4
# intial nan: 3.53 %, after out nan: 4.63 %, final nan: 0.0 %, after check nan: 1.07 %
# video name: 042424_Cam3_TrNum15_IS_KL006R.mp4
# intial nan: 0.57 %, after out nan: 1.23 %, final nan: 0.0 %, after check nan: 0.55 %
# video name: 042424_Cam3_TrNum2_IS_KL006G.mp4
# intial nan: 1.69 %, after out nan: 2.83 %, final nan: 0.0 %, after check nan: 1.16 %
# video name: 042424_Cam3_TrNum16_IS_KL006G.mp4
# intial nan: 1.28 %, after out nan: 2.22 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 042424_Cam3_TrNum13_PV_KL006Y.mp4
# intial nan: 1.29 %, after out nan: 2.06 %, final nan: 0.0 %, after check nan: 0.57 %
# video name: 042424_Cam3_TrNum1_PV_KL006Y.mp4
# intial nan: 1.42 %, after out nan: 2.33 %, final nan: 0.0 %, after check nan: 0.84 %
# video name: 042424_Cam4_TrNum13_PV_KL007B.mp4
# intial nan: 1.18 %, after out nan: 2.84 %, final nan: 0.0 %, after check nan: 1.53 %
# video name: 042424_Cam4_TrNum1_IS_KL007G.mp4
# intial nan: 1.35 %, after out nan: 2.38 %, final nan: 0.0 %, after check nan: 1.17 %
# video name: 042424_Cam4_TrNum16_PV_KL007R.mp4
# intial nan: 1.48 %, after out nan: 2.97 %, final nan: 0.0 %, after check nan: 1.46 %
# video name: 042424_Cam4_TrNum14_IS_KL007Y.mp4
# intial nan: 0.7 %, after out nan: 1.49 %, final nan: 0.0 %, after check nan: 0.56 %
# video name: 042424_Cam4_TrNum2_PV_KL007B.mp4
# intial nan: 2.33 %, after out nan: 3.61 %, final nan: 0.0 %, after check nan: 1.39 %
# video name: 042424_Cam4_TrNum3_IS_KL007Y.mp4
# intial nan: 1.22 %, after out nan: 2.15 %, final nan: 0.0 %, after check nan: 0.86 %
# video name: 042424_Cam4_TrNum15_IS_KL007G.mp4
# intial nan: 2.55 %, after out nan: 3.7 %, final nan: 0.0 %, after check nan: 1.35 %
# video name: 042424_Cam4_TrNum4_PV_KL007R.mp4
# intial nan: 1.66 %, after out nan: 2.84 %, final nan: 0.0 %, after check nan: 1.25 %
# video name: 042424_Cam1_TrNum13_IS_KL008G.mp4
# intial nan: 4.83 %, after out nan: 5.48 %, final nan: 0.0 %, after check nan: 0.5 %
# video name: 042424_Cam1_TrNum15_PV_KL008R.mp4
# intial nan: 5.21 %, after out nan: 6.25 %, final nan: 0.0 %, after check nan: 1.09 %
# video name: 042424_Cam1_TrNum14_PV_KL008Y.mp4
# intial nan: 4.54 %, after out nan: 5.65 %, final nan: 0.0 %, after check nan: 1.14 %
# video name: 042424_Cam1_TrNum4_IS_KL008B.mp4
# intial nan: 4.57 %, after out nan: 5.29 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 042424_Cam1_TrNum2_PV_KL008Y.mp4
# intial nan: 5.74 %, after out nan: 6.44 %, final nan: 0.0 %, after check nan: 0.53 %
# video name: 042424_Cam1_TrNum16_IS_KL008B.mp4
# intial nan: 5.42 %, after out nan: 6.07 %, final nan: 0.0 %, after check nan: 0.62 %
# video name: 042424_Cam1_TrNum3_IS_KL008G.mp4
# intial nan: 4.91 %, after out nan: 5.51 %, final nan: 0.0 %, after check nan: 0.55 %
# video name: 042424_Cam1_TrNum1_PV_KL008R.mp4
# intial nan: 7.28 %, after out nan: 8.09 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 042624_Cam2_TrNum4_PV_KL001G.mp4
# intial nan: 5.01 %, after out nan: 5.79 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 042624_Cam2_TrNum3_IS_KL001B.mp4
# intial nan: 3.77 %, after out nan: 4.46 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 042624_Cam2_TrNum13_IS_KL001B.mp4
# intial nan: 4.37 %, after out nan: 5.13 %, final nan: 0.0 %, after check nan: 0.9 %
# video name: 042624_Cam2_TrNum15_PV_KL001R.mp4
# intial nan: 4.84 %, after out nan: 5.56 %, final nan: 0.0 %, after check nan: 0.64 %
# video name: 042624_Cam2_TrNum16_IS_KL001Y.mp4
# intial nan: 2.96 %, after out nan: 3.78 %, final nan: 0.0 %, after check nan: 0.73 %
# video name: 042624_Cam2_TrNum14_PV_KL001G.mp4
# intial nan: 2.74 %, after out nan: 3.44 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 042624_Cam2_TrNum1_IS_KL001Y.mp4
# intial nan: 2.13 %, after out nan: 3.01 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042624_Cam2_TrNum2_PV_KL001R.mp4
# intial nan: 6.02 %, after out nan: 6.75 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 042624_Cam3_TrNum2_IS_KL002B.mp4
# intial nan: 2.05 %, after out nan: 2.95 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 042624_Cam3_TrNum14_IS_KL002Y.mp4
# intial nan: 2.14 %, after out nan: 2.76 %, final nan: 0.0 %, after check nan: 0.44 %
# video name: 042624_Cam3_TrNum3_PV_KL002R.mp4
# intial nan: 1.38 %, after out nan: 2.01 %, final nan: 0.0 %, after check nan: 0.51 %
# video name: 042624_Cam3_TrNum15_PV_KL002R.mp4
# intial nan: 1.02 %, after out nan: 1.54 %, final nan: 0.0 %, after check nan: 0.33 %
# video name: 042624_Cam3_TrNum1_IS_KL002Y.mp4
# intial nan: 1.72 %, after out nan: 2.7 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 042624_Cam3_TrNum4_PV_KL002G.mp4
# intial nan: 1.75 %, after out nan: 2.74 %, final nan: 0.0 %, after check nan: 1.07 %
# video name: 042624_Cam3_TrNum16_PV_KL002G.mp4
# intial nan: 2.33 %, after out nan: 3.14 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042624_Cam3_TrNum13_IS_KL002B.mp4
# intial nan: 2.61 %, after out nan: 3.52 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 042624_Cam1_TrNum1_IS_KL003G.mp4
# intial nan: 4.42 %, after out nan: 5.11 %, final nan: 0.0 %, after check nan: 0.57 %
# video name: 042624_Cam1_TrNum15_PV_KL003R.mp4
# intial nan: 3.61 %, after out nan: 4.41 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 042624_Cam1_TrNum2_PV_KL003Y.mp4
# intial nan: 3.19 %, after out nan: 4.05 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042624_Cam1_TrNum14_IS_KL003G.mp4
# intial nan: 4.86 %, after out nan: 5.32 %, final nan: 0.0 %, after check nan: 0.35 %
# video name: 042624_Cam1_TrNum4_PV_KL003R.mp4
# intial nan: 3.59 %, after out nan: 4.28 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 042624_Cam1_TrNum3_IS_KL003B.mp4
# intial nan: 3.4 %, after out nan: 4.18 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 042624_Cam1_TrNum16_IS_KL003B.mp4
# intial nan: 4.02 %, after out nan: 4.86 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 042624_Cam1_TrNum13_PV_KL003Y.mp4
# intial nan: 2.93 %, after out nan: 3.59 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 042624_Cam4_TrNum4_PV_KL004B.mp4
# intial nan: 0.84 %, after out nan: 2.2 %, final nan: 0.0 %, after check nan: 1.27 %
# video name: 042624_Cam4_TrNum13_PV_KL004B.mp4
# intial nan: 1.07 %, after out nan: 2.18 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 042624_Cam4_TrNum14_IS_KL004G.mp4
# intial nan: 1.22 %, after out nan: 1.77 %, final nan: 0.0 %, after check nan: 0.49 %
# video name: 042624_Cam4_TrNum16_PV_KL004Y.mp4
# intial nan: 1.49 %, after out nan: 2.8 %, final nan: 0.0 %, after check nan: 1.07 %
# video name: 042624_Cam4_TrNum3_PV_KL004Y.mp4
# intial nan: 5.52 %, after out nan: 6.62 %, final nan: 0.0 %, after check nan: 1.35 %
# video name: 042624_Cam4_TrNum1_IS_KL004R.mp4
# intial nan: 1.81 %, after out nan: 2.91 %, final nan: 0.0 %, after check nan: 1.18 %
# video name: 042624_Cam4_TrNum15_IS_KL004R.mp4
# intial nan: 1.52 %, after out nan: 2.41 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 042624_Cam4_TrNum2_IS_KL004G.mp4
# intial nan: 1.78 %, after out nan: 2.61 %, final nan: 0.0 %, after check nan: 0.91 %
# video name: 042924_Cam4_TrNum3_IS_KL005B.mp4
# intial nan: 1.31 %, after out nan: 2.31 %, final nan: 0.0 %, after check nan: 1.07 %
# video name: 042924_Cam4_TrNum15_IS_KL005Y.mp4
# intial nan: 1.25 %, after out nan: 2.52 %, final nan: 0.0 %, after check nan: 1.3 %
# video name: 042924_Cam4_TrNum16_PV_KL005G.mp4
# intial nan: 1.23 %, after out nan: 2.29 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 042924_Cam4_TrNum14_IS_KL005B.mp4
# intial nan: 2.04 %, after out nan: 3.19 %, final nan: 0.0 %, after check nan: 1.2 %
# video name: 042924_Cam4_TrNum1_IS_KL005Y.mp4
# intial nan: 2.26 %, after out nan: 3.35 %, final nan: 0.0 %, after check nan: 1.13 %
# video name: 042924_Cam4_TrNum13_PV_KL005R.mp4
# intial nan: 2.48 %, after out nan: 3.52 %, final nan: 0.0 %, after check nan: 1.14 %
# video name: 042924_Cam4_TrNum4_PV_KL005R.mp4
# intial nan: 1.36 %, after out nan: 2.45 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 042924_Cam4_TrNum2_PV_KL005G.mp4
# intial nan: 1.22 %, after out nan: 2.22 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 042924_Cam1_TrNum16_PV_KL006Y.mp4
# intial nan: 4.39 %, after out nan: 5.33 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 042924_Cam1_TrNum3_IS_KL006R.mp4
# intial nan: 2.1 %, after out nan: 2.84 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 042924_Cam1_TrNum4_IS_KL006G.mp4
# intial nan: 2.92 %, after out nan: 3.87 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 042924_Cam1_TrNum14_PV_KL006B.mp4
# intial nan: 3.38 %, after out nan: 4.41 %, final nan: 0.0 %, after check nan: 1.09 %
# video name: 042924_Cam1_TrNum13_IS_KL006G.mp4
# intial nan: 1.64 %, after out nan: 2.5 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 042924_Cam1_TrNum2_PV_KL006B.mp4
# intial nan: 2.77 %, after out nan: 3.59 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 042924_Cam1_TrNum15_IS_KL006R.mp4
# intial nan: 1.79 %, after out nan: 2.44 %, final nan: 0.0 %, after check nan: 0.52 %
# video name: 042924_Cam1_TrNum1_PV_KL006Y.mp4
# intial nan: 2.57 %, after out nan: 3.63 %, final nan: 0.0 %, after check nan: 1.09 %
# video name: 042924_Cam3_TrNum13_IS_KL007G.mp4
# intial nan: 1.05 %, after out nan: 1.86 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 042924_Cam3_TrNum14_PV_KL007B.mp4
# intial nan: 1.48 %, after out nan: 2.53 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 042924_Cam3_TrNum2_IS_KL007Y.mp4
# intial nan: 1.72 %, after out nan: 2.48 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 042924_Cam3_TrNum1_PV_KL007R.mp4
# intial nan: 2.1 %, after out nan: 3.01 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 042924_Cam3_TrNum16_IS_KL007Y.mp4
# intial nan: 0.56 %, after out nan: 1.19 %, final nan: 0.0 %, after check nan: 0.52 %
# video name: 042924_Cam3_TrNum3_PV_KL007B.mp4
# intial nan: 2.26 %, after out nan: 3.17 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 042924_Cam3_TrNum15_PV_KL007R.mp4
# intial nan: 0.93 %, after out nan: 2.24 %, final nan: 0.0 %, after check nan: 1.37 %
# video name: 042924_Cam3_TrNum4_IS_KL007G.mp4
# intial nan: 2.39 %, after out nan: 3.43 %, final nan: 0.0 %, after check nan: 1.18 %
# video name: 042924_Cam2_TrNum3_IS_KL008G.mp4
# intial nan: 5.68 %, after out nan: 6.46 %, final nan: 0.0 %, after check nan: 0.76 %
# video name: 042924_Cam2_TrNum2_PV_KL008R.mp4
# intial nan: 2.44 %, after out nan: 3.23 %, final nan: 0.0 %, after check nan: 0.84 %
# video name: 042924_Cam2_TrNum15_PV_KL008Y.mp4
# intial nan: 1.74 %, after out nan: 2.68 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 042924_Cam2_TrNum4_IS_KL008B.mp4
# intial nan: 2.64 %, after out nan: 3.45 %, final nan: 0.0 %, after check nan: 0.83 %
# video name: 042924_Cam2_TrNum14_PV_KL008R.mp4
# intial nan: 1.94 %, after out nan: 3.04 %, final nan: 0.0 %, after check nan: 1.18 %
# video name: 042924_Cam2_TrNum1_PV_KL008Y.mp4
# intial nan: 3.22 %, after out nan: 4.03 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 042924_Cam2_TrNum16_IS_KL008G.mp4
# intial nan: 1.83 %, after out nan: 2.61 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 042924_Cam2_TrNum13_IS_KL008B.mp4
# intial nan: 1.0 %, after out nan: 1.63 %, final nan: 0.0 %, after check nan: 0.58 %
# video name: 043024_Cam2_TrNum4_PV_KL001G.mp4
# intial nan: 4.51 %, after out nan: 5.15 %, final nan: 0.0 %, after check nan: 0.67 %
# video name: 043024_Cam2_TrNum2_PV_KL001R.mp4
# intial nan: 5.37 %, after out nan: 6.06 %, final nan: 0.0 %, after check nan: 0.59 %
# video name: 043024_Cam2_TrNum15_PV_KL001R.mp4
# intial nan: 2.83 %, after out nan: 3.65 %, final nan: 0.0 %, after check nan: 0.67 %
# video name: 043024_Cam2_TrNum1_IS_KL001Y.mp4
# intial nan: 5.35 %, after out nan: 6.05 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 043024_Cam2_TrNum14_PV_KL001G.mp4
# intial nan: 1.54 %, after out nan: 2.37 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 043024_Cam2_TrNum3_IS_KL001B.mp4
# intial nan: 5.51 %, after out nan: 6.1 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 043024_Cam2_TrNum16_IS_KL001Y.mp4
# intial nan: 2.96 %, after out nan: 3.83 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 043024_Cam2_TrNum13_IS_KL001B.mp4
# intial nan: 2.89 %, after out nan: 3.68 %, final nan: 0.0 %, after check nan: 0.91 %
# video name: 043024_Cam3_TrNum13_IS_KL002B.mp4
# intial nan: 0.96 %, after out nan: 1.81 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 043024_Cam3_TrNum1_IS_KL002Y.mp4
# intial nan: 1.84 %, after out nan: 2.88 %, final nan: 0.0 %, after check nan: 1.11 %
# video name: 043024_Cam3_TrNum4_PV_KL002G.mp4
# intial nan: 2.5 %, after out nan: 3.32 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 043024_Cam3_TrNum14_IS_KL002Y.mp4
# intial nan: 1.67 %, after out nan: 2.64 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 043024_Cam3_TrNum2_IS_KL002B.mp4
# intial nan: 2.05 %, after out nan: 2.94 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 043024_Cam3_TrNum16_PV_KL002G.mp4
# intial nan: 2.29 %, after out nan: 3.14 %, final nan: 0.0 %, after check nan: 0.82 %
# video name: 043024_Cam3_TrNum15_PV_KL002R.mp4
# intial nan: 2.19 %, after out nan: 2.9 %, final nan: 0.0 %, after check nan: 0.53 %
# video name: 043024_Cam3_TrNum3_PV_KL002R.mp4
# intial nan: 1.48 %, after out nan: 2.05 %, final nan: 0.0 %, after check nan: 0.47 %
# video name: 043024_Cam1_TrNum14_IS_KL003G.mp4
# intial nan: 3.46 %, after out nan: 4.0 %, final nan: 0.0 %, after check nan: 0.46 %
# video name: 043024_Cam1_TrNum13_PV_KL003Y.mp4
# intial nan: 3.31 %, after out nan: 4.25 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 043024_Cam1_TrNum2_PV_KL003Y.mp4
# intial nan: 4.17 %, after out nan: 4.92 %, final nan: 0.0 %, after check nan: 0.66 %
# video name: 043024_Cam1_TrNum1_IS_KL003G.mp4
# intial nan: 3.36 %, after out nan: 4.0 %, final nan: 0.0 %, after check nan: 0.6 %
# video name: 043024_Cam1_TrNum16_IS_KL003B.mp4
# intial nan: 9.47 %, after out nan: 10.23 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 043024_Cam1_TrNum3_IS_KL003B.mp4
# intial nan: 2.42 %, after out nan: 3.16 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 043024_Cam1_TrNum4_PV_KL003R.mp4
# intial nan: 3.03 %, after out nan: 4.09 %, final nan: 0.0 %, after check nan: 0.9 %
# video name: 043024_Cam1_TrNum15_PV_KL003R.mp4
# intial nan: 3.33 %, after out nan: 3.99 %, final nan: 0.0 %, after check nan: 0.5 %
# video name: 043024_Cam4_TrNum14_IS_KL004G.mp4
# intial nan: 1.96 %, after out nan: 2.66 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 043024_Cam4_TrNum3_PV_KL004Y.mp4
# intial nan: 3.02 %, after out nan: 4.17 %, final nan: 0.0 %, after check nan: 1.09 %
# video name: 043024_Cam4_TrNum16_PV_KL004Y.mp4
# intial nan: 1.54 %, after out nan: 2.84 %, final nan: 0.0 %, after check nan: 1.27 %
# video name: 043024_Cam4_TrNum4_PV_KL004B.mp4
# intial nan: 1.32 %, after out nan: 2.39 %, final nan: 0.0 %, after check nan: 1.14 %
# video name: 043024_Cam4_TrNum15_IS_KL004R.mp4
# intial nan: 1.76 %, after out nan: 2.73 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 043024_Cam4_TrNum13_PV_KL004B.mp4
# intial nan: 1.21 %, after out nan: 2.4 %, final nan: 0.0 %, after check nan: 1.23 %
# video name: 043024_Cam4_TrNum2_IS_KL004G.mp4
# intial nan: 1.86 %, after out nan: 2.65 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 043024_Cam4_TrNum1_IS_KL004R.mp4
# intial nan: 2.16 %, after out nan: 3.28 %, final nan: 0.0 %, after check nan: 1.15 %
# video name: 050124_Cam2_TrNum4_PV_KL005G.mp4
# intial nan: 2.7 %, after out nan: 3.45 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 050124_Cam2_TrNum2_PV_KL005R.mp4
# intial nan: 2.18 %, after out nan: 2.9 %, final nan: 0.0 %, after check nan: 0.62 %
# video name: 050124_Cam2_TrNum15_PV_KL005R.mp4
# intial nan: 2.22 %, after out nan: 3.06 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 050124_Cam2_TrNum1_IS_KL005Y.mp4
# intial nan: 3.14 %, after out nan: 3.98 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 050124_Cam2_TrNum14_PV_KL005G.mp4
# intial nan: 1.68 %, after out nan: 2.5 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 050124_Cam2_TrNum13_IS_KL005Y.mp4
# intial nan: 4.5 %, after out nan: 5.62 %, final nan: 0.0 %, after check nan: 1.18 %
# video name: 050124_Cam2_TrNum3_IS_KL005B.mp4
# intial nan: 2.43 %, after out nan: 3.15 %, final nan: 0.0 %, after check nan: 0.75 %
# video name: 050124_Cam2_TrNum16_IS_KL005B.mp4
# intial nan: 1.32 %, after out nan: 2.19 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 050124_Cam3_TrNum14_IS_KL006R.mp4
# intial nan: 1.06 %, after out nan: 1.84 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 050124_Cam3_TrNum15_PV_KL006B.mp4
# intial nan: 1.41 %, after out nan: 2.21 %, final nan: 0.0 %, after check nan: 0.76 %
# video name: 050124_Cam3_TrNum4_PV_KL006Y.mp4
# intial nan: 1.41 %, after out nan: 2.33 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 050124_Cam3_TrNum13_IS_KL006G.mp4
# intial nan: 1.4 %, after out nan: 2.09 %, final nan: 0.0 %, after check nan: 0.57 %
# video name: 050124_Cam3_TrNum2_IS_KL006G.mp4
# intial nan: 2.03 %, after out nan: 2.92 %, final nan: 0.0 %, after check nan: 0.83 %
# video name: 050124_Cam3_TrNum3_PV_KL006B.mp4
# intial nan: 1.88 %, after out nan: 2.69 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 050124_Cam3_TrNum1_IS_KL006R.mp4
# intial nan: 1.51 %, after out nan: 2.48 %, final nan: 0.0 %, after check nan: 1.09 %
# video name: 050124_Cam3_TrNum16_PV_KL006Y.mp4
# intial nan: 1.55 %, after out nan: 2.21 %, final nan: 0.0 %, after check nan: 0.53 %
# video name: 050124_Cam1_TrNum16_IS_KL007Y.mp4
# intial nan: 1.59 %, after out nan: 2.41 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 050124_Cam1_TrNum13_PV_KL007R.mp4
# intial nan: 3.33 %, after out nan: 4.2 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 050124_Cam1_TrNum2_PV_KL007B.mp4
# intial nan: 4.45 %, after out nan: 5.22 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 050124_Cam1_TrNum14_IS_KL007G.mp4
# intial nan: 1.54 %, after out nan: 2.26 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 050124_Cam1_TrNum4_PV_KL007R.mp4
# intial nan: 3.79 %, after out nan: 4.66 %, final nan: 0.0 %, after check nan: 0.9 %
# video name: 050124_Cam1_TrNum1_IS_KL007G.mp4
# intial nan: 3.57 %, after out nan: 4.35 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 050124_Cam1_TrNum3_IS_KL007Y.mp4
# intial nan: 3.93 %, after out nan: 4.8 %, final nan: 0.0 %, after check nan: 0.86 %
# video name: 050124_Cam1_TrNum15_PV_KL007B.mp4
# intial nan: 3.34 %, after out nan: 4.18 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 050124_Cam4_TrNum15_IS_KL008G.mp4
# intial nan: 2.8 %, after out nan: 3.67 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 050124_Cam4_TrNum14_IS_KL008B.mp4
# intial nan: 2.41 %, after out nan: 3.45 %, final nan: 0.0 %, after check nan: 1.33 %
# video name: 050124_Cam4_TrNum13_PV_KL008R.mp4
# intial nan: 2.36 %, after out nan: 3.34 %, final nan: 0.0 %, after check nan: 1.04 %
# video name: 050124_Cam4_TrNum4_PV_KL008R.mp4
# intial nan: 2.14 %, after out nan: 3.06 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 050124_Cam4_TrNum1_IS_KL008B.mp4
# intial nan: 1.96 %, after out nan: 3.02 %, final nan: 0.0 %, after check nan: 1.14 %
# video name: 050124_Cam4_TrNum16_PV_KL008Y.mp4
# intial nan: 2.39 %, after out nan: 3.65 %, final nan: 0.0 %, after check nan: 1.15 %
# video name: 050124_Cam4_TrNum2_IS_KL008G.mp4
# intial nan: 2.71 %, after out nan: 3.62 %, final nan: 0.0 %, after check nan: 1.08 %
# video name: 050124_Cam4_TrNum3_PV_KL008Y.mp4
# intial nan: 2.35 %, after out nan: 3.36 %, final nan: 0.0 %, after check nan: 1.21 %
# video name: 050324_Cam4_TrNum4_PV_KL001R.mp4
# intial nan: 2.14 %, after out nan: 3.27 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 050324_Cam4_TrNum3_IS_KL001B.mp4
# intial nan: 2.13 %, after out nan: 3.02 %, final nan: 0.0 %, after check nan: 1.11 %
# video name: 050324_Cam4_TrNum15_IS_KL001B.mp4
# intial nan: 2.68 %, after out nan: 3.69 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 050324_Cam4_TrNum13_PV_KL001R.mp4
# intial nan: 2.51 %, after out nan: 3.27 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 050324_Cam4_TrNum14_IS_KL001Y.mp4
# intial nan: 2.28 %, after out nan: 3.31 %, final nan: 0.0 %, after check nan: 1.03 %
# video name: 050324_Cam4_TrNum1_IS_KL001Y.mp4
# intial nan: 10.89 %, after out nan: 12.05 %, final nan: 0.0 %, after check nan: 1.46 %
# video name: 050324_Cam4_TrNum16_PV_KL001G.mp4
# intial nan: 2.38 %, after out nan: 3.34 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 050324_Cam4_TrNum2_PV_KL001G.mp4
# intial nan: 2.77 %, after out nan: 3.93 %, final nan: 0.0 %, after check nan: 1.15 %
# video name: 050324_Cam1_TrNum14_PV_KL002R.mp4
# intial nan: 4.13 %, after out nan: 5.18 %, final nan: 0.0 %, after check nan: 1.08 %
# video name: 050324_Cam1_TrNum15_IS_KL002Y.mp4
# intial nan: 3.49 %, after out nan: 4.31 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 050324_Cam1_TrNum4_IS_KL002B.mp4
# intial nan: 3.58 %, after out nan: 4.46 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 050324_Cam1_TrNum13_IS_KL002B.mp4
# intial nan: 1.72 %, after out nan: 2.95 %, final nan: 0.0 %, after check nan: 1.31 %
# video name: 050324_Cam1_TrNum2_PV_KL002R.mp4
# intial nan: 2.55 %, after out nan: 3.32 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 050324_Cam1_TrNum1_PV_KL002G.mp4
# intial nan: 5.26 %, after out nan: 6.44 %, final nan: 0.0 %, after check nan: 1.23 %
# video name: 050324_Cam1_TrNum16_PV_KL002G.mp4
# intial nan: 3.05 %, after out nan: 3.64 %, final nan: 0.0 %, after check nan: 0.52 %
# video name: 050324_Cam1_TrNum3_IS_KL002Y.mp4
# intial nan: 3.09 %, after out nan: 3.73 %, final nan: 0.0 %, after check nan: 0.62 %
# video name: 050324_Cam3_TrNum14_PV_KL003R.mp4
# intial nan: 2.24 %, after out nan: 2.81 %, final nan: 0.0 %, after check nan: 0.42 %
# video name: 050324_Cam3_TrNum2_IS_KL003B.mp4
# intial nan: 1.24 %, after out nan: 2.07 %, final nan: 0.0 %, after check nan: 0.83 %
# video name: 050324_Cam3_TrNum4_IS_KL003G.mp4
# intial nan: 2.23 %, after out nan: 2.9 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 050324_Cam3_TrNum1_PV_KL003R.mp4
# intial nan: 1.81 %, after out nan: 2.74 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 050324_Cam3_TrNum16_IS_KL003B.mp4
# intial nan: 2.29 %, after out nan: 3.25 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 050324_Cam3_TrNum3_PV_KL003Y.mp4
# intial nan: 6.02 %, after out nan: 6.92 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 050324_Cam3_TrNum13_IS_KL003G.mp4
# intial nan: 3.59 %, after out nan: 4.1 %, final nan: 0.0 %, after check nan: 0.43 %
# video name: 050324_Cam3_TrNum15_PV_KL003Y.mp4
# intial nan: 1.56 %, after out nan: 2.07 %, final nan: 0.0 %, after check nan: 0.36 %
# video name: 050324_Cam2_TrNum3_IS_KL004G.mp4
# intial nan: 3.47 %, after out nan: 4.09 %, final nan: 0.0 %, after check nan: 0.52 %
# video name: 050324_Cam2_TrNum15_PV_KL004Y.mp4
# intial nan: 2.26 %, after out nan: 3.4 %, final nan: 0.0 %, after check nan: 1.11 %
# video name: 050324_Cam2_TrNum14_PV_KL004B.mp4
# intial nan: 2.58 %, after out nan: 3.46 %, final nan: 0.0 %, after check nan: 0.86 %
# video name: 050324_Cam2_TrNum2_PV_KL004B.mp4
# intial nan: 3.82 %, after out nan: 4.89 %, final nan: 0.0 %, after check nan: 1.08 %
# video name: 050324_Cam2_TrNum13_IS_KL004G.mp4
# intial nan: 2.3 %, after out nan: 3.18 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 050324_Cam2_TrNum4_IS_KL004R.mp4
# intial nan: 5.25 %, after out nan: 5.86 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 050324_Cam2_TrNum1_PV_KL004Y.mp4
# intial nan: 4.27 %, after out nan: 5.14 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 050324_Cam2_TrNum16_IS_KL004R.mp4
# intial nan: 6.44 %, after out nan: 7.42 %, final nan: 0.0 %, after check nan: 1.08 %
# video name: 050524_Cam4_TrNum4_IS_KL005B.mp4
# intial nan: 2.45 %, after out nan: 3.54 %, final nan: 0.0 %, after check nan: 1.19 %
# video name: 050524_Cam4_TrNum14_PV_KL005R.mp4
# intial nan: 2.01 %, after out nan: 3.31 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 050524_Cam4_TrNum15_PV_KL005G.mp4
# intial nan: 2.28 %, after out nan: 3.29 %, final nan: 0.0 %, after check nan: 0.76 %
# video name: 050524_Cam4_TrNum16_IS_KL005Y.mp4
# intial nan: 4.52 %, after out nan: 5.89 %, final nan: 0.0 %, after check nan: 1.34 %
# video name: 050524_Cam4_TrNum2_PV_KL005G.mp4
# intial nan: 1.81 %, after out nan: 2.78 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 050524_Cam4_TrNum1_IS_KL005Y.mp4
# intial nan: 2.78 %, after out nan: 3.99 %, final nan: 0.0 %, after check nan: 1.27 %
# video name: 050524_Cam4_TrNum13_IS_KL005B.mp4
# intial nan: 3.36 %, after out nan: 4.35 %, final nan: 0.0 %, after check nan: 1.1 %
# video name: 050524_Cam4_TrNum3_PV_KL005R.mp4
# intial nan: 2.05 %, after out nan: 3.08 %, final nan: 0.0 %, after check nan: 1.0 %
# video name: 050524_Cam3_TrNum15_PV_KL006B.mp4
# intial nan: 2.91 %, after out nan: 3.69 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 050524_Cam3_TrNum4_IS_KL006G.mp4
# intial nan: 1.54 %, after out nan: 2.35 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 050524_Cam3_TrNum13_IS_KL006R.mp4
# intial nan: 0.62 %, after out nan: 1.21 %, final nan: 0.0 %, after check nan: 0.37 %
# video name: 050524_Cam3_TrNum2_IS_KL006R.mp4
# intial nan: 1.4 %, after out nan: 2.04 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 050524_Cam3_TrNum1_PV_KL006B.mp4
# intial nan: 1.38 %, after out nan: 2.25 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 050524_Cam3_TrNum3_PV_KL006Y.mp4
# intial nan: 1.47 %, after out nan: 2.23 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 050524_Cam3_TrNum14_PV_KL006Y.mp4
# intial nan: 1.73 %, after out nan: 2.42 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 050524_Cam3_TrNum16_IS_KL006G.mp4
# intial nan: 1.85 %, after out nan: 2.55 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 050524_Cam2_TrNum16_IS_KL007G.mp4
# intial nan: 5.17 %, after out nan: 5.86 %, final nan: 0.0 %, after check nan: 0.65 %
# video name: 050524_Cam2_TrNum4_IS_KL007G.mp4
# intial nan: 5.11 %, after out nan: 5.93 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 050524_Cam2_TrNum14_PV_KL007R.mp4
# intial nan: 4.75 %, after out nan: 5.95 %, final nan: 0.0 %, after check nan: 1.37 %
# video name: 050524_Cam2_TrNum15_PV_KL007B.mp4
# intial nan: 5.09 %, after out nan: 6.07 %, final nan: 0.0 %, after check nan: 1.06 %
# video name: 050524_Cam2_TrNum13_IS_KL007Y.mp4
# ...
# video name: 092624_Cam1_TrNum15_IS_KL003B.mp4
# intial nan: 4.25 %, after out nan: 5.09 %, final nan: 0.0 %, after check nan: 0.98 %
# video name: 092624_Cam1_TrNum7_IS_KL003B.mp4
# intial nan: 6.68 %, after out nan: 7.4 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 092624_Cam1_TrNum5_IS_KL005Y.mp4
# intial nan: 7.04 %, after out nan: 7.69 %, final nan: 0.0 %, after check nan: 0.76 %
# video name: 092624_Cam1_TrNum1_PV_KL005G.mp4
# intial nan: 8.09 %, after out nan: 9.08 %, final nan: 0.0 %, after check nan: 1.22 %
# video name: 092624_Cam1_TrNum6_IS_KL003G.mp4
# intial nan: 7.46 %, after out nan: 8.1 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 092624_Cam1_TrNum3_PV_KL003Y.mp4
# intial nan: 10.02 %, after out nan: 11.03 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 092724_Cam2_TrNum3_IS_KL003B.mp4
# intial nan: 3.58 %, after out nan: 4.64 %, final nan: 0.0 %, after check nan: 1.06 %
# video name: 092724_Cam2_TrNum2_IS_KL005B.mp4
# intial nan: 3.53 %, after out nan: 4.46 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 092724_Cam2_TrNum7_PV_KL003R.mp4
# intial nan: 4.31 %, after out nan: 5.13 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 092724_Cam2_TrNum5_PV_KL005G.mp4
# intial nan: 4.5 %, after out nan: 5.39 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 092724_Cam2_TrNum16_IS_KL007Y.mp4
# intial nan: 4.01 %, after out nan: 4.56 %, final nan: 0.0 %, after check nan: 0.6 %
# video name: 092724_Cam2_TrNum8_IS_KL007Y.mp4
# intial nan: 5.89 %, after out nan: 6.48 %, final nan: 0.0 %, after check nan: 0.6 %
# video name: 092724_Cam2_TrNum4_PV_KL007B.mp4
# intial nan: 5.2 %, after out nan: 6.06 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 092724_Cam2_TrNum6_IS_KL003G.mp4
# intial nan: 3.8 %, after out nan: 4.44 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 092724_Cam2_TrNum1_PV_KL007R.mp4
# intial nan: 5.04 %, after out nan: 5.9 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 092724_Cam1_TrNum5_PV_KL006B.mp4
# intial nan: 9.31 %, after out nan: 10.19 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 092724_Cam1_TrNum6_PV_KL008Y.mp4
# intial nan: 10.37 %, after out nan: 11.32 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 092724_Cam1_TrNum4_IS_KL006R.mp4
# intial nan: 4.43 %, after out nan: 5.28 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 092724_Cam1_TrNum3_IS_KL002Y.mp4
# intial nan: 11.07 %, after out nan: 11.86 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 092724_Cam1_TrNum2_PV_KL006Y.mp4
# intial nan: 10.14 %, after out nan: 11.03 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 092724_Cam1_TrNum8_IS_KL008G.mp4
# intial nan: 7.36 %, after out nan: 7.97 %, final nan: 0.0 %, after check nan: 0.57 %
# video name: 092724_Cam1_TrNum16_IS_KL008G.mp4
# intial nan: 6.54 %, after out nan: 7.22 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 093024_Cam2_TrNum6_IS_KL001Y.mp4
# intial nan: 5.81 %, after out nan: 6.72 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 093024_Cam2_TrNum1_IS_KL005B.mp4
# intial nan: 3.05 %, after out nan: 3.98 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 093024_Cam2_TrNum16_IS_KL004G.mp4
# intial nan: 3.12 %, after out nan: 3.72 %, final nan: 0.0 %, after check nan: 0.63 %
# video name: 093024_Cam2_TrNum3_PV_KL004B.mp4
# intial nan: 6.84 %, after out nan: 7.81 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 093024_Cam2_TrNum4_PV_KL008Y.mp4
# intial nan: 4.73 %, after out nan: 5.75 %, final nan: 0.0 %, after check nan: 0.9 %
# video name: 093024_Cam2_TrNum2_PV_KL001R.mp4
# intial nan: 5.03 %, after out nan: 6.17 %, final nan: 0.0 %, after check nan: 1.1 %
# video name: 093024_Cam2_TrNum8_IS_KL004G.mp4
# intial nan: 6.56 %, after out nan: 7.38 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 093024_Cam2_TrNum5_PV_KL004Y.mp4
# intial nan: 5.96 %, after out nan: 7.1 %, final nan: 0.0 %, after check nan: 1.11 %
# video name: 093024_Cam2_TrNum7_IS_KL008B.mp4
# intial nan: 2.15 %, after out nan: 3.05 %, final nan: 0.0 %, after check nan: 0.83 %
# video name: 093024_Cam1_TrNum5_IS_KL003B.mp4
# intial nan: 8.86 %, after out nan: 9.86 %, final nan: 0.0 %, after check nan: 1.14 %
# video name: 093024_Cam1_TrNum2_PV_KL007B.mp4
# intial nan: 10.53 %, after out nan: 11.53 %, final nan: 0.0 %, after check nan: 0.96 %
# video name: 093024_Cam1_TrNum7_PV_KL003R.mp4
# intial nan: 8.84 %, after out nan: 9.79 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 093024_Cam1_TrNum4_IS_KL005B.mp4
# intial nan: 6.04 %, after out nan: 6.85 %, final nan: 0.0 %, after check nan: 0.91 %
# video name: 093024_Cam1_TrNum8_IS_KL007Y.mp4
# intial nan: 7.52 %, after out nan: 8.19 %, final nan: 0.0 %, after check nan: 0.75 %
# video name: 093024_Cam1_TrNum1_PV_KL007R.mp4
# intial nan: 11.63 %, after out nan: 12.54 %, final nan: 0.0 %, after check nan: 0.91 %
# video name: 093024_Cam1_TrNum16_IS_KL007Y.mp4
# intial nan: 2.73 %, after out nan: 3.28 %, final nan: 0.0 %, after check nan: 0.5 %
# video name: 093024_Cam1_TrNum6_IS_KL003G.mp4
# intial nan: 8.4 %, after out nan: 9.18 %, final nan: 0.0 %, after check nan: 0.86 %
# video name: 093024_Cam1_TrNum3_PV_KL005G.mp4
# intial nan: 10.25 %, after out nan: 10.99 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 100124_Cam2_TrNum5_PV_KL008Y.mp4
# intial nan: 6.57 %, after out nan: 7.33 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 100124_Cam2_TrNum8_IS_KL004G.mp4
# intial nan: 6.8 %, after out nan: 7.48 %, final nan: 0.0 %, after check nan: 0.69 %
# video name: 100124_Cam2_TrNum1_PV_KL001R.mp4
# intial nan: 4.52 %, after out nan: 5.66 %, final nan: 0.0 %, after check nan: 1.23 %
# video name: 100124_Cam2_TrNum3_IS_KL001Y.mp4
# intial nan: 3.46 %, after out nan: 4.39 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 100124_Cam2_TrNum4_IS_KL008B.mp4
# intial nan: 3.68 %, after out nan: 4.49 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 100124_Cam2_TrNum2_PV_KL004Y.mp4
# intial nan: 7.56 %, after out nan: 8.7 %, final nan: 0.0 %, after check nan: 1.27 %
# video name: 100124_Cam2_TrNum7_IS_KL005B.mp4
# intial nan: 3.36 %, after out nan: 4.2 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 100124_Cam2_TrNum6_PV_KL004B.mp4
# intial nan: 7.67 %, after out nan: 8.62 %, final nan: 0.0 %, after check nan: 1.07 %
# video name: 100124_Cam2_TrNum16_IS_KL004G.mp4
# intial nan: 2.03 %, after out nan: 2.61 %, final nan: 0.0 %, after check nan: 0.56 %
# video name: 100124_Cam1_TrNum3_IS_KL008B.mp4
# intial nan: 4.51 %, after out nan: 5.35 %, final nan: 0.0 %, after check nan: 0.82 %
# video name: 100124_Cam1_TrNum16_IS_KL008G.mp4
# intial nan: 6.2 %, after out nan: 6.84 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 100124_Cam1_TrNum7_PV_KL006B.mp4
# intial nan: 11.26 %, after out nan: 12.19 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 100124_Cam1_TrNum5_IS_KL002Y.mp4
# intial nan: 5.79 %, after out nan: 6.74 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 100124_Cam1_TrNum4_PV_KL006Y.mp4
# intial nan: 9.93 %, after out nan: 10.81 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 100124_Cam1_TrNum8_IS_KL008G.mp4
# intial nan: 8.34 %, after out nan: 8.96 %, final nan: 0.0 %, after check nan: 0.6 %
# video name: 100124_Cam1_TrNum2_PV_KL008Y.mp4
# intial nan: 10.47 %, after out nan: 11.28 %, final nan: 0.0 %, after check nan: 0.87 %
# video name: 100124_Cam1_TrNum6_IS_KL006R.mp4
# intial nan: 5.68 %, after out nan: 6.34 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 100224_Cam2_TrNum3_IS_KL003B.mp4
# intial nan: 6.06 %, after out nan: 7.02 %, final nan: 0.0 %, after check nan: 1.05 %
# video name: 100224_Cam2_TrNum4_PV_KL003R.mp4
# intial nan: 6.62 %, after out nan: 7.43 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 100224_Cam2_TrNum2_PV_KL002R.mp4
# intial nan: 8.41 %, after out nan: 9.17 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 100224_Cam2_TrNum7_IS_KL002Y.mp4
# intial nan: 2.84 %, after out nan: 3.13 %, final nan: 0.0 %, after check nan: 0.46 %
# video name: 100224_Cam2_TrNum6_PV_KL002G.mp4
# intial nan: 8.37 %, after out nan: 9.3 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 100224_Cam2_TrNum15_IS_KL002Y.mp4
# intial nan: 4.62 %, after out nan: 5.16 %, final nan: 0.0 %, after check nan: 0.58 %
# video name: 100224_Cam2_TrNum1_IS_KL002B.mp4
# intial nan: 5.56 %, after out nan: 6.64 %, final nan: 0.0 %, after check nan: 1.16 %
# video name: 100224_Cam2_TrNum5_IS_KL006R.mp4
# intial nan: 5.02 %, after out nan: 5.53 %, final nan: 0.0 %, after check nan: 0.41 %
# video name: 100224_Cam1_TrNum5_PV_KL006B.mp4
# intial nan: 8.95 %, after out nan: 9.86 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 100224_Cam1_TrNum7_IS_KL006G.mp4
# intial nan: 6.54 %, after out nan: 7.25 %, final nan: 0.0 %, after check nan: 0.76 %
# video name: 100224_Cam1_TrNum2_PV_KL008Y.mp4
# intial nan: 8.95 %, after out nan: 9.79 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 100224_Cam1_TrNum3_IS_KL006R.mp4
# intial nan: 6.8 %, after out nan: 7.32 %, final nan: 0.0 %, after check nan: 0.68 %
# video name: 100224_Cam1_TrNum15_IS_KL006G.mp4
# intial nan: 3.9 %, after out nan: 4.42 %, final nan: 0.0 %, after check nan: 0.61 %
# video name: 100224_Cam1_TrNum1_IS_KL008B.mp4
# intial nan: 2.68 %, after out nan: 3.44 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 100224_Cam1_TrNum6_PV_KL006Y.mp4
# intial nan: 11.14 %, after out nan: 12.02 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 100224_Cam1_TrNum4_IS_KL005B.mp4
# intial nan: 6.1 %, after out nan: 6.9 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 100324_Cam1_TrNum4_IS_KL002B.mp4
# intial nan: 9.98 %, after out nan: 10.66 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 100324_Cam1_TrNum9_IS_KL002B.mp4
# intial nan: 9.86 %, after out nan: 10.57 %, final nan: 0.0 %, after check nan: 0.84 %
# video name: 100324_Cam1_TrNum2_IS_KL002Y.mp4
# intial nan: 8.76 %, after out nan: 9.37 %, final nan: 0.0 %, after check nan: 0.75 %
# video name: 100324_Cam1_TrNum3_PV_KL002G.mp4
# intial nan: 9.73 %, after out nan: 10.48 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 100324_Cam1_TrNum1_PV_KL002R.mp4
# intial nan: 8.35 %, after out nan: 8.99 %, final nan: 0.0 %, after check nan: 0.62 %
# video name: 100324_Cam2_TrNum4_IS_KL003B.mp4
# intial nan: 10.51 %, after out nan: 11.06 %, final nan: 0.0 %, after check nan: 0.76 %
# video name: 100324_Cam2_TrNum1_PV_KL003R.mp4
# intial nan: 11.24 %, after out nan: 12.24 %, final nan: 0.0 %, after check nan: 1.01 %
# video name: 100324_Cam2_TrNum3_PV_KL003Y.mp4
# intial nan: 11.64 %, after out nan: 12.59 %, final nan: 0.0 %, after check nan: 0.92 %
# video name: 100324_Cam2_TrNum2_IS_KL003G.mp4
# intial nan: 10.42 %, after out nan: 11.14 %, final nan: 0.0 %, after check nan: 0.72 %
# video name: 100324_Cam2_TrNum9_IS_KL003B.mp4
# intial nan: 7.93 %, after out nan: 8.54 %, final nan: 0.0 %, after check nan: 0.74 %
# video name: 100324_Cam1_TrNum9_IS_KL005Y.mp4
# intial nan: 10.14 %, after out nan: 10.74 %, final nan: 0.0 %, after check nan: 0.71 %
# video name: 100324_Cam1_TrNum3_IS_KL005B.mp4
# intial nan: 5.86 %, after out nan: 6.56 %, final nan: 0.0 %, after check nan: 0.82 %
# video name: 100324_Cam1_TrNum1_PV_KL005R.mp4
# intial nan: 9.98 %, after out nan: 10.86 %, final nan: 0.0 %, after check nan: 0.79 %
# video name: 100324_Cam1_TrNum2_PV_KL005G.mp4
# intial nan: 8.54 %, after out nan: 9.37 %, final nan: 0.0 %, after check nan: 0.89 %
# video name: 100324_Cam1_TrNum4_IS_KL005Y.mp4
# intial nan: 8.08 %, after out nan: 8.59 %, final nan: 0.0 %, after check nan: 0.53 %
# video name: 100324_Cam2_TrNum4_IS_KL006G.mp4
# intial nan: 8.28 %, after out nan: 8.93 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 100324_Cam2_TrNum2_PV_KL006Y.mp4
# intial nan: 7.63 %, after out nan: 8.34 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 100324_Cam2_TrNum3_IS_KL006R.mp4
# intial nan: 6.12 %, after out nan: 6.58 %, final nan: 0.0 %, after check nan: 0.48 %
# video name: 100324_Cam2_TrNum1_PV_KL006B.mp4
# intial nan: 10.14 %, after out nan: 11.13 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 100324_Cam2_TrNum9_IS_KL006G.mp4
# intial nan: 6.36 %, after out nan: 7.14 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 101724_Cam2_TrNum3_IS_HF004Y.mp4
# intial nan: 15.41 %, after out nan: 16.05 %, final nan: 0.0 %, after check nan: 0.8 %
# video name: 101724_Cam2_TrNum1_IS_HF003B.mp4
# intial nan: 8.53 %, after out nan: 9.29 %, final nan: 0.0 %, after check nan: 0.94 %
# video name: 101724_Cam2_TrNum2_IS_HF001R.mp4
# intial nan: 6.33 %, after out nan: 6.96 %, final nan: 0.0 %, after check nan: 0.6 %
# video name: 101724_Cam2_TrNum8_IS_HF004Y.mp4
# intial nan: 11.45 %, after out nan: 12.11 %, final nan: 0.0 %, after check nan: 0.7 %
# video name: 101724_Cam1_TrNum2_IS_HF006G.mp4
# intial nan: 8.97 %, after out nan: 9.77 %, final nan: 0.0 %, after check nan: 0.9 %
# video name: 101724_Cam1_TrNum1_IS_HF002G.mp4
# intial nan: 6.2 %, after out nan: 7.14 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 101724_Cam1_TrNum8_IS_HF008Y.mp4
# intial nan: 13.43 %, after out nan: 14.09 %, final nan: 0.0 %, after check nan: 0.78 %
# video name: 101724_Cam1_TrNum3_IS_HF008Y.mp4
# intial nan: 14.75 %, after out nan: 15.39 %, final nan: 0.0 %, after check nan: 0.75 %
# video name: 101824_Cam1_TrNum3_IS_HF002G.mp4
# intial nan: 17.84 %, after out nan: 18.66 %, final nan: 0.0 %, after check nan: 0.93 %
# video name: 101824_Cam1_TrNum2_IS_KL004Y.mp4
# intial nan: 26.17 %, after out nan: 27.08 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 101824_Cam1_TrNum1_IS_KL003B.mp4
# intial nan: 21.69 %, after out nan: 22.63 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 101824_Cam2_TrNum3_IS_HF001R.mp4
# intial nan: 11.28 %, after out nan: 12.13 %, final nan: 0.0 %, after check nan: 0.81 %
# video name: 101824_Cam2_TrNum2_IS_KL008Y.mp4
# intial nan: 17.04 %, after out nan: 17.99 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 101824_Cam2_TrNum1_IS_KL006G.mp4
# intial nan: 22.73 %, after out nan: 23.69 %, final nan: 0.0 %, after check nan: 0.85 %
# video name: 102124_Cam1_TrNum2_IS_HF006G.mp4
# intial nan: 54.21 %, after out nan: 55.09 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 102124_Cam1_TrNum1_IS_HF003B.mp4
# intial nan: 47.02 %, after out nan: 48.04 %, final nan: 0.0 %, after check nan: 1.22 %
# video name: 102124_Cam1_TrNum3_IS_HF004Y.mp4
# intial nan: 54.67 %, after out nan: 55.68 %, final nan: 0.0 %, after check nan: 1.06 %
# video name: 102124_Cam1_TrNum8_IS_HF004Y.mp4
# could not fill locations...
# intial nan: 56.55 %, after out nan: 57.24 %, final nan: 6.67 %, after check nan: 7.73 %
# video name: 102124_Cam2_TrNum1_IS_HF006G.mp4
# intial nan: 36.01 %, after out nan: 37.07 %, final nan: 0.0 %, after check nan: 1.1 %
# video name: 102124_Cam2_TrNum3_IS_HF008Y.mp4
# intial nan: 32.88 %, after out nan: 33.95 %, final nan: 0.0 %, after check nan: 0.97 %
# video name: 102124_Cam2_TrNum8_IS_HF008Y.mp4
# intial nan: 43.66 %, after out nan: 44.45 %, final nan: 0.0 %, after check nan: 0.86 %
# video name: 102124_Cam2_TrNum2_IS_HF001R.mp4
# intial nan: 30.4 %, after out nan: 31.56 %, final nan: 0.0 %, after check nan: 1.15 %
# video name: 102224_Cam2_TrNum3_IS_HF003B.mp4
# intial nan: 29.07 %, after out nan: 30.34 %, final nan: 0.0 %, after check nan: 0.95 %
# video name: 102224_Cam2_TrNum1_IS_HF004Y.mp4
# intial nan: 32.05 %, after out nan: 33.08 %, final nan: 0.0 %, after check nan: 1.12 %
# video name: 102224_Cam2_TrNum2_IS_HF001R.mp4
# intial nan: 31.84 %, after out nan: 32.96 %, final nan: 0.0 %, after check nan: 1.14 %
# video name: 102224_Cam1_TrNum2_IS_HF008Y.mp4
# intial nan: 51.08 %, after out nan: 51.99 %, final nan: 0.0 %, after check nan: 0.88 %
# video name: 102224_Cam1_TrNum1_IS_HF001R.mp4
# intial nan: 50.73 %, after out nan: 51.56 %, final nan: 0.0 %, after check nan: 0.99 %
# video name: 102224_Cam1_TrNum3_IS_HF006G.mp4
# intial nan: 55.0 %, after out nan: 55.88 %, final nan: 0.0 %, after check nan: 1.0 %
# totals:
# intial nan: 4.76 %, after out nan: 5.6 %, final nan: 0.07 %, after check nan: 0.93 %
# time elapse: 3005.191201210022

# %%
np.save('single_vids.npy', all_vids)
np.save('single_errors.npy', all_errors)

# %% [markdown]
# # check our work... (abt 18 vids that I WOULDN'T trust!!)

# %%
file = open('single_corrections_output.txt','r')
output = file.readlines()

intial = []
after_out = []
after_fill = []
vid_name = []

stupid_flag = True
for line in output:
    if "video name" in line:
        vid_name.append(line[12:-1])
        stupid_flag = True
    if "could" in line:
        print("this is one of vids I couldn't do anything abt")
        print(vid_name[-1])
        vid_name.pop()
        stupid_flag = False

    if "intial" in line and stupid_flag:
        parsed = line.split('%')
        
        init_temp = float(parsed[0][12:])
        out_temp = float(parsed[1][16:])
        fill_temp = float(parsed[2][12:])
        intial.append(init_temp)
        after_out.append(out_temp)
        after_fill.append(fill_temp)
# Out:
# this is one of vids I couldn't do anything abt
# 091924_Cam2_TrNum15_IS_KL005Y.mp4
# this is one of vids I couldn't do anything abt
# 102124_Cam1_TrNum8_IS_HF004Y.mp4

# %%
print("average over all videos:")
print(f'intial nan: {round(np.mean(intial), 2)} %, after out nan: {round(np.mean(after_out), 2)} %, final nan: {round(np.mean(after_fill), 2)} %')
# Out:
# average over all videos:
# intial nan: 4.64 %, after out nan: 5.5 %, final nan: 0.0 %

# %%
# so for some reason these predictions started out atrocious... YIKES, maybe wouldn't trust the correct files
for i, init in enumerate(intial):
    if init > 20:
        print(init, vid_name[i])
# Out:
# 26.17 101824_Cam1_TrNum2_IS_KL004Y.mp4
# 21.69 101824_Cam1_TrNum1_IS_KL003B.mp4
# 22.73 101824_Cam2_TrNum1_IS_KL006G.mp4
# 54.21 102124_Cam1_TrNum2_IS_HF006G.mp4
# 47.02 102124_Cam1_TrNum1_IS_HF003B.mp4
# 54.67 102124_Cam1_TrNum3_IS_HF004Y.mp4
# 36.01 102124_Cam2_TrNum1_IS_HF006G.mp4
# 32.88 102124_Cam2_TrNum3_IS_HF008Y.mp4
# 43.66 102124_Cam2_TrNum8_IS_HF008Y.mp4
# 30.4 102124_Cam2_TrNum2_IS_HF001R.mp4
# 29.07 102224_Cam2_TrNum3_IS_HF003B.mp4
# 32.05 102224_Cam2_TrNum1_IS_HF004Y.mp4
# 31.84 102224_Cam2_TrNum2_IS_HF001R.mp4
# 51.08 102224_Cam1_TrNum2_IS_HF008Y.mp4
# 50.73 102224_Cam1_TrNum1_IS_HF001R.mp4
# 55.0 102224_Cam1_TrNum3_IS_HF006G.mp4
